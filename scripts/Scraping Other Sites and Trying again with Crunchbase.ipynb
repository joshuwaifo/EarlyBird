# %% [markdown]
# ## More complex scraping of crunchbase

# %%
# import webbrowser: used to open url in web browser
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
url = "https://www.crunchbase.com/app/search/companies"
# webbrowser.open(url)

# this is the goal to be extracted!!!!!!!

# %%
# !pip install requests
# !pip install bs4
# !pip install -U selenium
# Out:
# Requirement already up-to-date: selenium in /afs/inf.ed.ac.uk/user/s17/s1780019/miniconda3/envs/iaml/lib/python2.7/site-packages

# %%
# # enables the request to go through a browser and not be thought of as a bot
# headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'}

# res = requests.get(url, headers=headers)

# %%
driver = webdriver.Chrome(executable_path='../chromedriver') # Could be any other browser you have the drivers for
driver.get(url)
html = driver.page_source
code = BeautifulSoup(html,'html5lib')
print code
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta content="NOINDEX, NOFOLLOW" name="ROBOTS"/>
# <meta content="max-age=0" http-equiv="cache-control"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="0" http-equiv="expires"/>
# <meta content="Tue, 01 Jan 1980 1:00:00 GMT" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="10; url=/distil_r_blocked.html?Ref=/app/search/companies&amp;distil_RID=1C81FB70-A6BB-11E7-96E1-ACBCCA14809A&amp;distil_TID=20171001151342" http-equiv="refresh"/>
# <script type="text/javascript">
# 	(function(window){
# 		try {
# 			if (typeof sessionStorage !== 'undefined'){
# 				sessionStorage.setItem('distil_referrer', document.referrer);
# 			}
# 		} catch (e){}
# 	})(window);
# </script>
# ...

# %%
# crunchbase are really good

# %%
res.status_code #success so far

# %%
res.raise_for_status()

# %%
res.text

# %%
# function that takes a url and outputs the html on the url page

def extract_text(url):
    driver = webdriver.Chrome(executable_path='../chromedriver') # Could be any other browser you have the drivers for
    driver.get(url)
    html = driver.page_source
    code = BeautifulSoup(html,'html5lib')
    print code.prettify()

# %% [markdown]
# # Mattermark

# %%
mattermark_url = "https://mattermark.com/companies/alibaba.com"

# %%
extract_text(url=mattermark_url)
# Out:
# <!DOCTYPE html>
# <html class="wf-proximanova-n7-active wf-proximanova-n8-active wf-proximanova-i8-active wf-proximanova-n6-active wf-proximanova-n4-active wf-proximanova-n3-active wf-proximanova-n9-active wf-proximanova-i7-active wf-proximanova-i9-active wf-proximanova-n1-active wf-proximanova-i1-active wf-proximanova-i6-active wf-proximanova-i4-active wf-proximanova-i3-active wf-active" lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Alibaba Company Information - Mattermark
#   </title>
#   <link href="//dwhbf7aoykm92.cloudfront.net/mattermark.e752183551d9dfd31757.css" rel="stylesheet"/>
#   <link href="/app/assets/img/new/favicon.png" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %% [markdown]
# Mattermark may be extracted. The info above is from Alibaba company.
# The issue here is that we need to sign up. We could sign up for a free trial and extract what we need, but it appears doable. Let me know what info you would want from Mattermark.

# %% [markdown]
# # CB Insights

# %% [markdown]
# The website looks messy and from what I see, it may have info but hard to tell without logging in. I tried to sign up but it asked for an organisation email. If possible can someone sign up and send me the link of a page they would like to extract data from so that I can progress.

# %% [markdown]
# # AngelList

# %%
angelList_url = "https://angel.co/amplitude-analytics"

# %%
extract_text(url=angelList_url)
# Out:
# <!DOCTYPE html>
# <html class="notranslate scheme-lighter_gray_backdrop size-large responsive js no-touch csstransforms csstransitions smil no-overflowscrolling filereader no-force-desktop mm no-ml no-ms wf-alternategothicno3d-n4-active wf-dincondensedweb-n4-active wf-aktivgroteskstd-n3-active wf-aktivgroteskstd-n2-active wf-active" style="" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    Amplitude Analytics Careers, Funding, and Management Team | AngelList
#   </title>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="y6W6xuVEukyJCRS1pfQ+7/WcAti5HVOCN9ay9E0x/syGF8mh3uDtnMvY6DRHuVSKJdFgQnyYqBk4dytze1pStg==" name="csrf-token"/>
#   <!--
# ...
# -->
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="en_US" http-equiv="Content-Language"/>
#   <meta content="c2y_K2CiLmGeet7GUQc9e3RVGp_gCOxUC4IdJg_RBVo" name="google-site-verification"/>
# ...

# %% [markdown]
# Here is an example of the extraction of info from the angelList webpage for Amplitude analytics. The only piece of information displayed is the name of the company, the other pieces of info like Employees, Past employees are encoded on the side of AngelList. In the future, I could try to decode it but is a huge task.

# %% [markdown]
# # DealRoom

# %% [markdown]
# I signed up for the website in order to see the kind of information they have. Searching the companies section of their website there was company information regarding industry, business model., location, valuation etc.
# Looks so far like it will have a lot of info. Now checking to see if the webscraper works well on this website.

# %%
dealroom_url = "https://app.dealroom.co/companies"

# %%
extract_text(url=dealroom_url)
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Dealroom -  Companies
#   </title>
#   <link href="/favicon.png" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:400,300italic,200,200italic,300,400italic,600,600italic,700,700italic,900,900italic" rel="stylesheet" type="text/css"/>
#   <link href="/./vendor.2e657eb45f79eee57350d447e15e0eaf.css" rel="stylesheet" type="text/css"/>
#   <link href="/./main.6a25e2007d5d50ca7e53980864078b59.css" rel="stylesheet" type="text/css"/>
#   <meta content="noarchive" name="robots"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, shrink-to-fit=no" name="viewport"/>
#   <meta content="website" property="og:type"/>
#   <script async="" src="https://widget.intercom.io/widget/y5emaigw" type="text/javascript">
#   </script>
# ...

# %% [markdown]
# Similarly to AngelList, the information has been encoded however I saw that they have an export function BUT only for premium account holders. If you guys already have links with them, can you pass your login so I could extract info from them.

# %% [markdown]
# # Preqin

# %% [markdown]
# Preqin's website contained no data that carried meaningful information when extracted. The only way to get access from their datasource is by subscribing with them and even that is a selective process. So not sure, what the plan was regarding Preqin. They could have useful information but at the moment, the website content itself isnt really encouraging

# %% [markdown]
# # Quid

# %% [markdown]
# Quid may have startup information but the access I have to their website prevents anything worthwhile from being done. The only thing one could do their was request a demonstration.

# %% [markdown]
# # Venture Scanner

# %% [markdown]
# Similar to Preqin, you cannot tell much from the website itsel without subscrbing and one has to contact them for pricing information

# %% [markdown]
# To summarise, Mattermark gives the greatest hope currently. What I am going to do to progress is work with the Data already given from Pitchbook and then build on from there, hopefully more data can be provided along the way

# %% [markdown]
# In addition, I think it would be good at the moment to use the crunchbase pro which costs 29 dollars per month. But gives you daily exports or you could make a custom agreement with them and they could give API access which offers more flexibility.

# %% [markdown]
# https://about.crunchbase.com/products/pricing/
