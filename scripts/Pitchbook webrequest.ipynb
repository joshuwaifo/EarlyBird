# %% [markdown]
# # Pitchbook Web Request

# %% [markdown]
# Curl is a unix command, used to transfer or recieve data
#
# Here, I make a request to Pitchbook's company section of the website to return its information. There is no data here as Pitchbook, do not freely display it, the hope is that either using their API or logging in as a user , may allow me to use it.

# %%
webpage = "https://pitchbook.com/platform-data/companies"

# %% [markdown]
# Test to see if I can retrieve data from Pitchbook

# %%
# !curl $webpage
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>VC-Backed Companies | PE-Backed Companies | Startup Database</title>
# <meta name="description" content="PitchBook tracks over 300,000 private companies and their investment histories, valuations, growth rates and executive teams.">
#
#
# <meta property="og:title" content="List of Startups | VC-Backed Companies | PE-Backed Companies"/>
# <meta property="og:type" content="website"/>
# <meta property="og:url" content="https://pitchbook.com/platform-data/companies"/>
# <meta property="og:description" content="The PitchBook Platform tracks public & private companies, investors, limited partners, funds, mergers, acquisitions, PE & VC transactions, and the people involved. Check out the full scope of our data."/>
# <meta property="og:image" content="https://pitchbook.com/img/social-media/facebook/PitchBook-Facebook-Data.jpg?uq=LpOSAGq7"/>
#
#
# <meta name="twitter:card" content="summary_large_image">
# ...

# %% [markdown]
# The output above shows that the text and image links were retrieved from the request. This gives hope that given I can get a webpage that has the data on it, we are a go.

# %% [markdown]
# The example below uses wget which is a unix command that downloads textual information and stores it in a html. The data of the webrequest to Pitchbook's webpage above was stored in companies using the following wget command.

# %%
# !wget $webpage -P ../data/pitchbookTest
# Out:
# --2017-09-24 16:43:21--  https://pitchbook.com/platform-data/companies
# Resolving pitchbook.com (pitchbook.com)... 67.192.51.29
# Connecting to pitchbook.com (pitchbook.com)|67.192.51.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘../data/pitchbookTest/companies’
#
#     [ <=>                                   ] 28,080      --.-K/s   in 0.001s
#
# 2017-09-24 16:43:21 (53.0 MB/s) - ‘../data/pitchbookTest/companies’ saved [28080]

# %% [markdown]
# I have registered for the free trial for Pitchbook and will proceed further following the the next meeting (Monday 25th September), **SO FAR SO GOOD**
